# %% [markdown]
# # DataFabric Runtime Package Versions
#
# DataFabric runtime 의 대부분의 package 는 [pydatafabric package](https://pypi.org/project/pydatafabric) 에서 관리되고,
# 각 package/version 정보는 아래와 같다.

# %%
# !python3 -m pip list
# Out:
# Package                           Version
# --------------------------------- --------------
# absl-py                           1.2.0
# aiobotocore                       2.4.0
# aiohttp                           3.8.3
# aiohttp-retry                     2.8.3
# aioitertools                      0.11.0
# aiosignal                         1.2.0
# alembic                           1.8.0
# ansi2html                         1.8.0
# anyio                             3.6.1
# appdirs                           1.4.4
# argon2-cffi                       21.3.0
# argon2-cffi-bindings              21.2.0
# asttokens                         2.0.8
# astunparse                        1.6.3
# async-generator                   1.10
# async-timeout                     4.0.2
# asyncssh                          2.8.1
# atpublic                          3.1.1
# attrs                             22.1.0
# Babel                             2.10.1
# backcall                          0.2.0
# ...
