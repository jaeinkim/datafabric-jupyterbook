# %% [markdown]
# ### 결과셋 새로운 테이블로 저장하기

# %%
query = "select * from smart-ruler-304409.common.hcard_features_0304 limit 10"
path = 'smart-ruler-304409.common.test_ctas'

# %%
from pydatafabric.gcp import load_query_result_to_table

load_query_result_to_table(path, query)
# Out:
# select * from smart-ruler-304409.common.hcard_features_0304 limit 10

# %% [markdown]
# ### CTAS 확인하기 Create Table As Select와 동일

# %%
from pydatafabric.gcp import get_bigquery_client

bq = get_bigquery_client(project="smart-ruler-304409")
df = bq.query("select * from smart-ruler-304409.common.test_ctas").to_dataframe()  #쿼리 결과를 dataframe으로 다운로드
df
# Out:
#                                              CUST_ID CORP_INDVL_DIVCD  \
# 0  fb7eceeaae55a88f438394e9be7e7b5122cc36f6deb057...            68002
# 1  2a2662eab1d81fc2add81971a81d7cedf70389540fda10...            68002
# 2  fb9ff124752e5e5cb74c638af31461c8cbb87bc5443154...            68002
# 3  9a5b550dc04fad2fc21d2058469f3cf137cd1a98e1c05b...            68002
# 4  ed8d678bc255849fdab83310bee402fb80c5cc0a436d2a...            68002
# 5  3824de30abfa473def31973c94653eb8cb4de76986bdcb...            68002
# 6  e2280f20e49f612c947cfc4ec5075e89d908401255862a...            68002
# 7  5914e4383a6d3752dff026f079dd907edfdeb80d31b5a3...            68002
# 8  0ad738954a31d5c3563ccabf637e5bc8238454eb6ae401...            68002
# 9  fdaec3c589152fdbf2aeb230368167de36f06bcec959f2...            68002
#
#   EMAIL_RCV_AGREE_DT  EMAIL_RCV_AGREE_DT_DUR GNDR_CD SMS_RCV_YN  \
# 0         2016-12-21                    1899       2          Y
# 1         2013-07-09                    3160       1          N
# ...
